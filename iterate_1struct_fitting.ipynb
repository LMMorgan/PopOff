# %%
import os
from fitting import FitModel
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt
import input_checker as ic
import json

# %%
def create_directory(head_directory_name, structure_number):
    directory = os.path.join(head_directory_name, str(structure_number))
    os.makedirs(directory)
    return directory

def setup_error_checks(include_labels, bounds_list, fit_data, params):
        if len(include_labels) != len(bounds_list):
            raise IndexError('include_labels and bounds_list are not of equal length. Check there are bounds associated with each label with the correct bound values.')
        for label, bounds in zip(include_labels, bounds_list):
            if label.startswith('dq_'):
                ic.check_coreshell(label, bounds, fit_data)
            elif label == 'q_scaling':
                ic.check_scaling_limits(label, bounds)
            elif '-' in label:
                ic.check_spring(label, bounds, params)
            elif '_a' in label or '_rho' in label or '_c' in label:
                ic.check_buckingham(label, bounds, params)
            else:
                raise TypeError('Label {} is not a valid label type'.format(label))
                
def get_forces(fit_data, values, args):
    fit_data.init_potential(values, args)
    ip_forces = fit_data.get_forces()
    dft_forces = fit_data.expected_forces()
    return dft_forces, ip_forces

# %% [markdown]
# ### Set up parameters for LiNiO2 with core-shell O-O

# %%
params = {}
params['core_shell'] = { 'Li': False, 'Ni': False, 'O': True }
params['charges'] = {'Li': +1.0,
                     'Ni': +3.0,
                     'O': {'core':  -2.0, #+0.960,
                           'shell': 0.0}} #-2.960}}
params['masses'] = {'Li': 6.941,
                    'Ni': 58.6934,
                    'O': {'core': 14.3991,
                          'shell': 1.5999} }
params['cs_springs'] = {'O-O' : [20.0, 0.0]}

distribution = {}
distribution['Li-O'] = {'bpp' : [663.111, 0.119, 0.0],
                        'sd' : [80, 0.01, 0.01]}
distribution['Ni-O'] = {'bpp' : [1393.540, 0.218, 0.000],
                        'sd'  : [80, 0.01, 0.01]}
distribution['O-O'] = {'bpp' : [25804.807, 0.284, 0.0],
                       'sd'  : [200, 0.01, 5]}

# %% [markdown]
# ### Set up the fitting parameters
# The lables and associated bounds

# %%
include_labels = ['dq_O', 'q_scaling', 'O-O spring', 'Li_O_a',     'Li_O_rho', 'Ni_O_a',      'Ni_O_rho', 'O_O_a',        'O_O_rho']
bounds_list = [(0.01, 4), (0.3,1.0),   (10.0,150.0), (100.0,50000.0),(0.01,1.0), (100.0,50000.0),(0.01,1.0), (150.0,50000.0),(0.01,1.0)]

# %% [markdown]
# ### Directory set up
# requires the head directory name and the number of structuers

# %%
head_directory_name = '1_structure_fits'
number_of_structures = 7

# %% [markdown]
# ### Runs the fit for each structure in the number of structures to its directory
# This copies the relivant poscar and outcar from the thermo directory to the working directory for each structure, then runs the fit and prints the output files to the correct output directory.
#
# Not very neatly done, but should work for now and can be tidied up later.

# %%
poscar_directory = os.path.join('poscars','thermos')
outcar_directory = os.path.join('outcars','thermos')
for structure in range(13,15):
    os.system('cp {}/POSCAR{} {}/{}'.format(poscar_directory, structure+1, 'poscars', 'POSCAR1'))
    os.system('cp {}/OUTCAR{} {}/{}'.format(outcar_directory, structure+1, 'outcars', 'OUTCAR1'))
    fit_data = FitModel.collect_info(params, distribution, supercell=[2,2,2])
    setup_error_checks(include_labels, bounds_list, fit_data, params)
    s = optimize.differential_evolution(fit_data.chi_squared_error, bounds=bounds_list, popsize=25,
                                        args=([include_labels]), maxiter=2000,
                                        disp=True, init='latinhypercube', workers=-1)
    dft_forces, ip_forces = get_forces(fit_data, s.x, include_labels)
    struct_directory = create_directory(head_directory_name, structure+1)
    np.savetxt('{}/dft_forces.dat'.format(struct_directory), dft_forces, fmt='%.10e', delimiter=' ')
    np.savetxt('{}/ip_forces.dat'.format(struct_directory), ip_forces, fmt='%.10e', delimiter=' ')
    with open('{}/error.dat'.format(struct_directory), 'w') as f:
        f.write(str(s.fun))
#     np.savetxt('{}/error.dat'.format(struct_directory), s.fun, fmt='%.10')
    potential_dict = {k:v for k, v in zip(include_labels, s.x)}
    with open('{}/potentials.json'.format(struct_directory), 'w') as f:
        json.dump(potential_dict, f)
# Out:
# Found elements: ['Li', 'Ni', 'O']
# differential_evolution step 1: f(x)= 0.778053
# differential_evolution step 2: f(x)= 0.315927
# differential_evolution step 3: f(x)= 0.315927
# differential_evolution step 4: f(x)= 0.315927
# differential_evolution step 5: f(x)= 0.315927
# differential_evolution step 6: f(x)= 0.315927
# differential_evolution step 7: f(x)= 0.315927
# differential_evolution step 8: f(x)= 0.315927
# differential_evolution step 9: f(x)= 0.315927
# differential_evolution step 10: f(x)= 0.315927
# differential_evolution step 11: f(x)= 0.315927
# differential_evolution step 12: f(x)= 0.315927
# differential_evolution step 13: f(x)= 0.315927
# differential_evolution step 14: f(x)= 0.315927
# differential_evolution step 15: f(x)= 0.304737
# differential_evolution step 16: f(x)= 0.304737
# differential_evolution step 17: f(x)= 0.304737
# differential_evolution step 18: f(x)= 0.304737
# differential_evolution step 19: f(x)= 0.304737
# differential_evolution step 20: f(x)= 0.304737
# differential_evolution step 21: f(x)= 0.304737
# differential_evolution step 22: f(x)= 0.304737
# differential_evolution step 23: f(x)= 0.290578
# differential_evolution step 24: f(x)= 0.290578
# differential_evolution step 25: f(x)= 0.258343
# differential_evolution step 26: f(x)= 0.258343
# differential_evolution step 27: f(x)= 0.258343
# differential_evolution step 28: f(x)= 0.258343
# differential_evolution step 29: f(x)= 0.242182
# differential_evolution step 30: f(x)= 0.242182
# differential_evolution step 31: f(x)= 0.242182
# differential_evolution step 32: f(x)= 0.242182
# differential_evolution step 33: f(x)= 0.242182
# differential_evolution step 34: f(x)= 0.242182
# differential_evolution step 35: f(x)= 0.242182
# differential_evolution step 36: f(x)= 0.242182
# differential_evolution step 37: f(x)= 0.242182
# differential_evolution step 38: f(x)= 0.242182
# differential_evolution step 39: f(x)= 0.242182
# differential_evolution step 40: f(x)= 0.242182
# differential_evolution step 41: f(x)= 0.242182
# differential_evolution step 42: f(x)= 0.242182
# differential_evolution step 43: f(x)= 0.242182
# differential_evolution step 44: f(x)= 0.242182
# differential_evolution step 45: f(x)= 0.242182
# differential_evolution step 46: f(x)= 0.242182
# differential_evolution step 47: f(x)= 0.242182
# differential_evolution step 48: f(x)= 0.242182
# differential_evolution step 49: f(x)= 0.242182
# differential_evolution step 50: f(x)= 0.242182
# differential_evolution step 51: f(x)= 0.242182
# differential_evolution step 52: f(x)= 0.242182
# differential_evolution step 53: f(x)= 0.242182
# differential_evolution step 54: f(x)= 0.242182
# differential_evolution step 55: f(x)= 0.242182
# differential_evolution step 56: f(x)= 0.242182
# differential_evolution step 57: f(x)= 0.238894
# differential_evolution step 58: f(x)= 0.238894
# differential_evolution step 59: f(x)= 0.235063
# differential_evolution step 60: f(x)= 0.235063
# differential_evolution step 61: f(x)= 0.233537
# differential_evolution step 62: f(x)= 0.233537
# differential_evolution step 63: f(x)= 0.233537
# differential_evolution step 64: f(x)= 0.230892
# differential_evolution step 65: f(x)= 0.230892
# differential_evolution step 66: f(x)= 0.230892
# differential_evolution step 67: f(x)= 0.229766
# differential_evolution step 68: f(x)= 0.229766
# differential_evolution step 69: f(x)= 0.229766
# differential_evolution step 70: f(x)= 0.227316
# differential_evolution step 71: f(x)= 0.227316
# differential_evolution step 72: f(x)= 0.227316
# differential_evolution step 73: f(x)= 0.227316
# differential_evolution step 74: f(x)= 0.227316
# differential_evolution step 75: f(x)= 0.227316
# differential_evolution step 76: f(x)= 0.227316
# differential_evolution step 77: f(x)= 0.227316
# differential_evolution step 78: f(x)= 0.227316
# differential_evolution step 79: f(x)= 0.227316
# differential_evolution step 80: f(x)= 0.227316
# differential_evolution step 81: f(x)= 0.227316
# differential_evolution step 82: f(x)= 0.227316
# differential_evolution step 83: f(x)= 0.227316
# differential_evolution step 84: f(x)= 0.227316
# differential_evolution step 85: f(x)= 0.227316
# differential_evolution step 86: f(x)= 0.227316
# differential_evolution step 87: f(x)= 0.227316
# differential_evolution step 88: f(x)= 0.227316
# differential_evolution step 89: f(x)= 0.227316
# differential_evolution step 90: f(x)= 0.227316
# differential_evolution step 91: f(x)= 0.227316
# differential_evolution step 92: f(x)= 0.227316
# differential_evolution step 93: f(x)= 0.22671
# differential_evolution step 94: f(x)= 0.226097
# differential_evolution step 95: f(x)= 0.226097
# differential_evolution step 96: f(x)= 0.226097
# differential_evolution step 97: f(x)= 0.225551
# differential_evolution step 98: f(x)= 0.225551
# differential_evolution step 99: f(x)= 0.224359
# differential_evolution step 100: f(x)= 0.224359
# differential_evolution step 101: f(x)= 0.224359
# differential_evolution step 102: f(x)= 0.224359
# differential_evolution step 103: f(x)= 0.224359
# differential_evolution step 104: f(x)= 0.224359
# differential_evolution step 105: f(x)= 0.224359
# differential_evolution step 106: f(x)= 0.224359
# differential_evolution step 107: f(x)= 0.224009
# differential_evolution step 108: f(x)= 0.224009
# differential_evolution step 109: f(x)= 0.224009
# differential_evolution step 110: f(x)= 0.224009
# differential_evolution step 111: f(x)= 0.224009
# differential_evolution step 112: f(x)= 0.224009
# differential_evolution step 113: f(x)= 0.224009
# differential_evolution step 114: f(x)= 0.224009
# differential_evolution step 115: f(x)= 0.224009
# differential_evolution step 116: f(x)= 0.224009
# differential_evolution step 117: f(x)= 0.223797
# differential_evolution step 118: f(x)= 0.223797
# differential_evolution step 119: f(x)= 0.223797
# differential_evolution step 120: f(x)= 0.223797
# differential_evolution step 121: f(x)= 0.223797
# differential_evolution step 122: f(x)= 0.223797
# differential_evolution step 123: f(x)= 0.223797
# differential_evolution step 124: f(x)= 0.223797
# differential_evolution step 125: f(x)= 0.223797
# Found elements: ['Li', 'Ni', 'O']
# differential_evolution step 1: f(x)= 1.80544
# differential_evolution step 2: f(x)= 1.64519
# differential_evolution step 3: f(x)= 0.588027
# differential_evolution step 4: f(x)= 0.559629
# differential_evolution step 5: f(x)= 0.559629
# differential_evolution step 6: f(x)= 0.305265
# differential_evolution step 7: f(x)= 0.305265
# differential_evolution step 8: f(x)= 0.305265
# differential_evolution step 9: f(x)= 0.305265
# differential_evolution step 10: f(x)= 0.305265
# differential_evolution step 11: f(x)= 0.305265
# differential_evolution step 12: f(x)= 0.305265
