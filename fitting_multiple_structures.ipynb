# %%
import os
from fitting import FitModel
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt
import input_checker as ic
import json

# %%
def create_directory(head_directory_name, structure_number):
    directory = os.path.join(head_directory_name, str(structure_number))
    os.makedirs(directory)
    return directory

def setup_error_checks(include_labels, bounds_list, fit_data, params):
        if len(include_labels) != len(bounds_list):
            raise IndexError('include_labels and bounds_list are not of equal length. Check there are bounds associated with each label with the correct bound values.')
        for label, bounds in zip(include_labels, bounds_list):
            if label.startswith('dq_'):
                ic.check_coreshell(label, bounds, fit_data)
            elif label == 'q_scaling':
                ic.check_scaling_limits(label, bounds)
            elif '-' in label:
                ic.check_spring(label, bounds, params)
            elif '_a' in label or '_rho' in label or '_c' in label:
                ic.check_buckingham(label, bounds, params)
            else:
                raise TypeError('Label {} is not a valid label type'.format(label))
                
def get_forces(fit_data, values, args):
    fit_data.init_potential(values, args)
    ip_forces = fit_data.get_forces()
    dft_forces = fit_data.expected_forces()
    return dft_forces, ip_forces

# %% [markdown]
# ### Set up parameters for LiNiO2 with core-shell O-O

# %%
params = {}
# params['core_shell'] = { 'Li': False, 'Ni': False, 'O': False }
# params['charges'] = {'Li': +1.0,
#                      'Ni': +3.0,
#                      'O': -2.0}
# params['masses'] = {'Li': 6.941,
#                     'Ni': 58.6934,
#                     'O': 15.999}
# params['cs_springs'] = {}

params['core_shell'] = { 'Li': False, 'Ni': False, 'O': True }
params['charges'] = {'Li': +1.0,
                     'Ni': +3.0,
                     'O': {'core':  -2.0, #+0.960,
                           'shell': 0.0}} #-2.960}}
params['masses'] = {'Li': 6.941,
                    'Ni': 58.6934,
                    'O': {'core': 14.3991,
                          'shell': 1.5999} }
params['cs_springs'] = {'O-O' : [20.0, 0.0]}

distribution = {}
distribution['Li-O'] = {'bpp' : [663.111, 0.119, 0.0],
                        'sd' : [80, 0.01, 0.01]}
distribution['Ni-O'] = {'bpp' : [1393.540, 0.218, 0.000],
                        'sd'  : [80, 0.01, 0.01]}
distribution['O-O'] = {'bpp' : [25804.807, 0.284, 0.0],
                       'sd'  : [200, 0.01, 5]}

# %% [markdown]
# ### Set up the fitting parameters
# The lables and associated bounds

# %%
include_labels = ['dq_O', 'q_scaling', 'O-O spring', 'Li_O_a',     'Li_O_rho', 'Ni_O_a',      'Ni_O_rho', 'O_O_a',        'O_O_rho']
bounds_list = [(0.01, 4), (0.3,1.0),   (10.0,150.0), (100.0,50000.0),(0.01,1.0), (100.0,50000.0),(0.01,1.0), (150.0,50000.0),(0.01,1.0)]

# %% [markdown]
# ### Directory set up
# Requires the head directory name, the number of structuers, number of structures to fit to, and number of fits to run.

# %%
tot_num_structures = 15 #Total number of structures in the pool
num_struct_to_fit = 1 #How many structures are in the fit
num_of_fits = 1 #How many fits to run
head_directory_name = '{}_stress_test'.format(num_struct_to_fit)

# %% [markdown]
# ### Randomly selecting sets of structures
# Creating 'num_of_fits' random sets of length 'num_struct_to_fit'

# %%
sets_of_structures = []
while len(sets_of_structures) < num_of_fits:
    struct_set = np.sort(np.random.randint(0,tot_num_structures, size=num_struct_to_fit), axis=0)
    if len(set(struct_set)) != num_struct_to_fit:
        continue
    if not any(np.array_equiv(struct_set, x) for x in sets_of_structures):
        sets_of_structures.append(struct_set) 
sets_of_structures = np.array(sets_of_structures)

# %% [markdown]
# ### Runs the fit for each structure in the number of structures to its directory
# This copies the relivant poscar and outcar from the thermo directory to the working directory for each structure, then runs the fit and prints the output files to the correct output directory.
#
# Not very neatly done, but should work for now and can be tidied up later.

# %%
poscar_directory = os.path.join('poscars','thermos')
outcar_directory = os.path.join('outcars','thermos')
for fit, structs in enumerate(sets_of_structures): 
    for struct_num, struct in enumerate(structs):
        os.system('cp {}/POSCAR{} {}/POSCAR{}'.format(poscar_directory, struct+1, 'poscars', struct_num+1))
        os.system('cp {}/OUTCAR{} {}/OUTCAR{}'.format(outcar_directory, struct+1, 'outcars', struct_num+1))
    fit_data = FitModel.collect_info(params, distribution, supercell=[2,2,2])
    setup_error_checks(include_labels, bounds_list, fit_data, params)
    s = optimize.differential_evolution(fit_data.chi_squared_error, bounds=bounds_list, popsize=25,
                                        args=([include_labels]), maxiter=2000,
                                        disp=True, init='latinhypercube', workers=-1)
    dft_forces, ip_forces = get_forces(fit_data, s.x, include_labels)
    local_struct_dir = '-'.join([ '{}'.format(struct+1) for struct in structs])
    struct_directory = create_directory(head_directory_name, local_struct_dir)
    np.savetxt('{}/dft_forces.dat'.format(struct_directory), dft_forces, fmt='%.10e', delimiter=' ')
    np.savetxt('{}/ip_forces.dat'.format(struct_directory), ip_forces, fmt='%.10e', delimiter=' ')
    with open('{}/error.dat'.format(struct_directory), 'w') as f:
        f.write(str(s.fun))
    potential_dict = {k:v for k, v in zip(include_labels, s.x)}
    with open('{}/potentials.json'.format(struct_directory), 'w') as f:
        json.dump(potential_dict, f)
# Out:
# Found elements: ['Li', 'Ni', 'O']
# /Users/lmm82/.pyenv/versions/3.7.3/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py:461: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   " updating='deferred'", UserWarning)
# differential_evolution step 1: f(x)= 4961.85
# differential_evolution step 2: f(x)= 4961.85
# differential_evolution step 3: f(x)= 4961.85
# differential_evolution step 4: f(x)= 4961.85
# differential_evolution step 5: f(x)= 2187.92
# differential_evolution step 6: f(x)= 622.508
# differential_evolution step 7: f(x)= 622.508
# differential_evolution step 8: f(x)= 479.118
# differential_evolution step 9: f(x)= 479.118
# differential_evolution step 10: f(x)= 479.118
# differential_evolution step 11: f(x)= 479.118
# differential_evolution step 12: f(x)= 479.118
# differential_evolution step 13: f(x)= 479.118
# differential_evolution step 14: f(x)= 479.118
# differential_evolution step 15: f(x)= 479.118
# differential_evolution step 16: f(x)= 369.24
# differential_evolution step 17: f(x)= 369.24
# differential_evolution step 18: f(x)= 369.24
# differential_evolution step 19: f(x)= 369.24
# differential_evolution step 20: f(x)= 369.24
# differential_evolution step 21: f(x)= 262.408
# differential_evolution step 22: f(x)= 262.408
# differential_evolution step 23: f(x)= 262.408
# differential_evolution step 24: f(x)= 262.408
# differential_evolution step 25: f(x)= 262.408
# differential_evolution step 26: f(x)= 234.292
# differential_evolution step 27: f(x)= 234.292
# differential_evolution step 28: f(x)= 234.292
# differential_evolution step 29: f(x)= 174.738
# differential_evolution step 30: f(x)= 131.841
# differential_evolution step 31: f(x)= 131.841
# differential_evolution step 32: f(x)= 131.841
# differential_evolution step 33: f(x)= 131.841
# differential_evolution step 34: f(x)= 131.841
# differential_evolution step 35: f(x)= 131.841
# differential_evolution step 36: f(x)= 131.841
# differential_evolution step 37: f(x)= 131.841
# differential_evolution step 38: f(x)= 131.841
# differential_evolution step 39: f(x)= 131.841
# differential_evolution step 40: f(x)= 131.841
# differential_evolution step 41: f(x)= 131.841
# differential_evolution step 42: f(x)= 131.841
# differential_evolution step 43: f(x)= 127.753
# differential_evolution step 44: f(x)= 127.753
# differential_evolution step 45: f(x)= 127.753
# differential_evolution step 46: f(x)= 127.753
# differential_evolution step 47: f(x)= 127.753
# differential_evolution step 48: f(x)= 127.753
# differential_evolution step 49: f(x)= 127.753
# differential_evolution step 50: f(x)= 127.753
# differential_evolution step 51: f(x)= 127.753
# differential_evolution step 52: f(x)= 117.075
# differential_evolution step 53: f(x)= 117.075
# differential_evolution step 54: f(x)= 117.075
# differential_evolution step 55: f(x)= 117.075
# differential_evolution step 56: f(x)= 117.075
# differential_evolution step 57: f(x)= 117.075
# differential_evolution step 58: f(x)= 114.547
# differential_evolution step 59: f(x)= 114.547
# differential_evolution step 60: f(x)= 114.547
# differential_evolution step 61: f(x)= 114.547
# differential_evolution step 62: f(x)= 114.547
# differential_evolution step 63: f(x)= 114.547
# differential_evolution step 64: f(x)= 114.547
# differential_evolution step 65: f(x)= 68.66
# differential_evolution step 66: f(x)= 21.9436
# differential_evolution step 67: f(x)= 21.9436
# differential_evolution step 68: f(x)= 21.9436
# differential_evolution step 69: f(x)= 21.9436
# differential_evolution step 70: f(x)= 21.9436
# differential_evolution step 71: f(x)= 21.9436
# differential_evolution step 72: f(x)= 21.9436
# differential_evolution step 73: f(x)= 21.9436
# differential_evolution step 74: f(x)= 21.9436
# differential_evolution step 75: f(x)= 21.9436
# differential_evolution step 76: f(x)= 21.9436
# differential_evolution step 77: f(x)= 21.9436
# differential_evolution step 78: f(x)= 21.9436
# differential_evolution step 79: f(x)= 21.9436
# differential_evolution step 80: f(x)= 21.9436
# differential_evolution step 81: f(x)= 21.9436
# differential_evolution step 82: f(x)= 21.9436
# differential_evolution step 83: f(x)= 21.9436
# differential_evolution step 84: f(x)= 21.9436
# differential_evolution step 85: f(x)= 21.9436
# differential_evolution step 86: f(x)= 21.9436
# differential_evolution step 87: f(x)= 21.9436
# differential_evolution step 88: f(x)= 21.9436
# differential_evolution step 89: f(x)= 21.9436
# differential_evolution step 90: f(x)= 21.9436
# differential_evolution step 91: f(x)= 21.9436
# differential_evolution step 92: f(x)= 21.9436
# differential_evolution step 93: f(x)= 21.9436
# differential_evolution step 94: f(x)= 21.9436
# differential_evolution step 95: f(x)= 21.9436
# differential_evolution step 96: f(x)= 21.9436
# differential_evolution step 97: f(x)= 21.9436
# differential_evolution step 98: f(x)= 21.9436
# differential_evolution step 99: f(x)= 21.9436
# differential_evolution step 100: f(x)= 21.9436
# differential_evolution step 101: f(x)= 21.9436
# differential_evolution step 102: f(x)= 21.9436
# differential_evolution step 103: f(x)= 21.9436
# differential_evolution step 104: f(x)= 21.9436
# differential_evolution step 105: f(x)= 21.9436
# differential_evolution step 106: f(x)= 21.9436
# differential_evolution step 107: f(x)= 21.9436
# differential_evolution step 108: f(x)= 21.9436
# differential_evolution step 109: f(x)= 21.9436
# differential_evolution step 110: f(x)= 21.9436
# differential_evolution step 111: f(x)= 21.9436
# differential_evolution step 112: f(x)= 15.7956
# differential_evolution step 113: f(x)= 15.7956
# differential_evolution step 114: f(x)= 15.7956
# differential_evolution step 115: f(x)= 15.7956
# differential_evolution step 116: f(x)= 15.7956
# differential_evolution step 117: f(x)= 15.7956
# differential_evolution step 118: f(x)= 15.7956
# differential_evolution step 119: f(x)= 15.7956
# differential_evolution step 120: f(x)= 13.222
# differential_evolution step 121: f(x)= 13.222
# differential_evolution step 122: f(x)= 13.222
# differential_evolution step 123: f(x)= 13.222
# differential_evolution step 124: f(x)= 13.222
# differential_evolution step 125: f(x)= 13.222
# differential_evolution step 126: f(x)= 13.222
# differential_evolution step 127: f(x)= 13.222
# differential_evolution step 128: f(x)= 13.222
# differential_evolution step 129: f(x)= 13.222
# differential_evolution step 130: f(x)= 13.222
# differential_evolution step 131: f(x)= 13.222
# differential_evolution step 132: f(x)= 13.222
# differential_evolution step 133: f(x)= 13.222
# differential_evolution step 134: f(x)= 9.33476
# differential_evolution step 135: f(x)= 9.33476
# differential_evolution step 136: f(x)= 9.33476
# differential_evolution step 137: f(x)= 9.33476
# differential_evolution step 138: f(x)= 9.33476
# differential_evolution step 139: f(x)= 9.33476
# differential_evolution step 140: f(x)= 9.33476
# differential_evolution step 141: f(x)= 9.33476
# differential_evolution step 142: f(x)= 9.33476
# differential_evolution step 143: f(x)= 9.33476
# differential_evolution step 144: f(x)= 9.33476
# differential_evolution step 145: f(x)= 9.33476
# differential_evolution step 146: f(x)= 5.57391
# differential_evolution step 147: f(x)= 5.57391
# differential_evolution step 148: f(x)= 5.57391
# differential_evolution step 149: f(x)= 5.57391
# differential_evolution step 150: f(x)= 4.66239
# differential_evolution step 151: f(x)= 4.66239
# differential_evolution step 152: f(x)= 4.66239
# differential_evolution step 153: f(x)= 4.66239
# differential_evolution step 154: f(x)= 4.66239
# differential_evolution step 155: f(x)= 4.66239
# differential_evolution step 156: f(x)= 4.66239
# differential_evolution step 157: f(x)= 4.66239
# differential_evolution step 158: f(x)= 4.66239
# differential_evolution step 159: f(x)= 4.66239
# differential_evolution step 160: f(x)= 4.66239
# differential_evolution step 161: f(x)= 4.66239
# differential_evolution step 162: f(x)= 4.66239
# differential_evolution step 163: f(x)= 4.66239
# differential_evolution step 164: f(x)= 4.66239
# differential_evolution step 165: f(x)= 4.66239
# differential_evolution step 166: f(x)= 4.66239
# differential_evolution step 167: f(x)= 4.66239
# differential_evolution step 168: f(x)= 4.66239
# differential_evolution step 169: f(x)= 4.66239
# differential_evolution step 170: f(x)= 4.66239
# differential_evolution step 171: f(x)= 4.66239
# differential_evolution step 172: f(x)= 4.66239
# differential_evolution step 173: f(x)= 4.66239
# differential_evolution step 174: f(x)= 3.02614
# differential_evolution step 175: f(x)= 3.02614
# differential_evolution step 176: f(x)= 3.02614
# differential_evolution step 177: f(x)= 3.02614
# differential_evolution step 178: f(x)= 3.02614
# differential_evolution step 179: f(x)= 3.02614
# differential_evolution step 180: f(x)= 3.02614
# differential_evolution step 181: f(x)= 3.02614
# differential_evolution step 182: f(x)= 3.02614
# differential_evolution step 183: f(x)= 3.02614
# differential_evolution step 184: f(x)= 3.02614
# differential_evolution step 185: f(x)= 3.02614
# differential_evolution step 186: f(x)= 3.02614
# differential_evolution step 187: f(x)= 3.02614
# differential_evolution step 188: f(x)= 3.02614
# differential_evolution step 189: f(x)= 3.02614
# differential_evolution step 190: f(x)= 3.02614
# differential_evolution step 191: f(x)= 3.02614
# differential_evolution step 192: f(x)= 3.02614
# differential_evolution step 193: f(x)= 3.02614
# differential_evolution step 194: f(x)= 3.02614
# differential_evolution step 195: f(x)= 3.02614
# differential_evolution step 196: f(x)= 3.02614
# differential_evolution step 197: f(x)= 3.02614
# differential_evolution step 198: f(x)= 3.02614
# differential_evolution step 199: f(x)= 3.02614
# differential_evolution step 200: f(x)= 3.02614
# differential_evolution step 201: f(x)= 3.02614
# differential_evolution step 202: f(x)= 3.02614
# differential_evolution step 203: f(x)= 3.02614
# differential_evolution step 204: f(x)= 3.02614
# differential_evolution step 205: f(x)= 3.02614
# differential_evolution step 206: f(x)= 3.02614
# differential_evolution step 207: f(x)= 3.02614
# differential_evolution step 208: f(x)= 3.02614
# differential_evolution step 209: f(x)= 2.91767
# differential_evolution step 210: f(x)= 2.91767
# differential_evolution step 211: f(x)= 2.91767
# differential_evolution step 212: f(x)= 2.91767
# differential_evolution step 213: f(x)= 2.91767
# differential_evolution step 214: f(x)= 2.91767
# differential_evolution step 215: f(x)= 2.91767
# differential_evolution step 216: f(x)= 2.91767
# differential_evolution step 217: f(x)= 2.91767
# differential_evolution step 218: f(x)= 2.91767
# differential_evolution step 219: f(x)= 2.91767
# differential_evolution step 220: f(x)= 2.91767
# differential_evolution step 221: f(x)= 2.91767
# differential_evolution step 222: f(x)= 2.91767
# differential_evolution step 223: f(x)= 2.91767
# differential_evolution step 224: f(x)= 2.91767
# differential_evolution step 225: f(x)= 2.91767
# differential_evolution step 226: f(x)= 2.91767
# differential_evolution step 227: f(x)= 2.91767
# differential_evolution step 228: f(x)= 2.91767
# differential_evolution step 229: f(x)= 2.91767
# differential_evolution step 230: f(x)= 2.91767
# differential_evolution step 231: f(x)= 2.91767
# differential_evolution step 232: f(x)= 2.91767
# differential_evolution step 233: f(x)= 2.91767
# differential_evolution step 234: f(x)= 2.91767
# differential_evolution step 235: f(x)= 2.91767
# differential_evolution step 236: f(x)= 2.91767
# differential_evolution step 237: f(x)= 2.91767
# differential_evolution step 238: f(x)= 2.91767
# differential_evolution step 239: f(x)= 2.91767
# differential_evolution step 240: f(x)= 2.91767
# differential_evolution step 241: f(x)= 2.91767
# differential_evolution step 242: f(x)= 2.91767
# differential_evolution step 243: f(x)= 2.91767
# differential_evolution step 244: f(x)= 2.91767
# differential_evolution step 245: f(x)= 2.82986
# differential_evolution step 246: f(x)= 2.82986
# differential_evolution step 247: f(x)= 2.82986
# differential_evolution step 248: f(x)= 2.82986
# differential_evolution step 249: f(x)= 2.82986
# differential_evolution step 250: f(x)= 2.82986
# differential_evolution step 251: f(x)= 2.82986
# differential_evolution step 252: f(x)= 2.82986
# differential_evolution step 253: f(x)= 2.82986
# differential_evolution step 254: f(x)= 2.82986
# differential_evolution step 255: f(x)= 2.82986
# differential_evolution step 256: f(x)= 2.82986
# differential_evolution step 257: f(x)= 2.82986
# differential_evolution step 258: f(x)= 2.82986
# differential_evolution step 259: f(x)= 2.82986
# differential_evolution step 260: f(x)= 2.82986
# differential_evolution step 261: f(x)= 2.82986
# differential_evolution step 262: f(x)= 2.82986
# differential_evolution step 263: f(x)= 2.73094
# differential_evolution step 264: f(x)= 2.73094
# differential_evolution step 265: f(x)= 2.73094
# differential_evolution step 266: f(x)= 2.73094
# differential_evolution step 267: f(x)= 2.73094
# differential_evolution step 268: f(x)= 2.40231
# differential_evolution step 269: f(x)= 2.40231
# differential_evolution step 270: f(x)= 2.40231
# differential_evolution step 271: f(x)= 2.40231
# differential_evolution step 272: f(x)= 2.40231
# differential_evolution step 273: f(x)= 2.40231
# differential_evolution step 274: f(x)= 2.40231
# differential_evolution step 275: f(x)= 2.40231
# differential_evolution step 276: f(x)= 2.40231
# differential_evolution step 277: f(x)= 2.40231
# differential_evolution step 278: f(x)= 2.40231
# differential_evolution step 279: f(x)= 2.40231
# differential_evolution step 280: f(x)= 2.40231
# differential_evolution step 281: f(x)= 2.40231
# differential_evolution step 282: f(x)= 2.40231
# differential_evolution step 283: f(x)= 2.40231
# differential_evolution step 284: f(x)= 2.40231
# differential_evolution step 285: f(x)= 2.40231
# differential_evolution step 286: f(x)= 2.40231
# differential_evolution step 287: f(x)= 2.40231
# differential_evolution step 288: f(x)= 2.40231
# differential_evolution step 289: f(x)= 2.29535
# differential_evolution step 290: f(x)= 2.29535
# differential_evolution step 291: f(x)= 2.29535
# differential_evolution step 292: f(x)= 2.29535
# differential_evolution step 293: f(x)= 2.29535
# differential_evolution step 294: f(x)= 2.29535
# differential_evolution step 295: f(x)= 2.29535
# differential_evolution step 296: f(x)= 2.29535
# differential_evolution step 297: f(x)= 2.29535
# differential_evolution step 298: f(x)= 2.29535
# differential_evolution step 299: f(x)= 2.29535
# differential_evolution step 300: f(x)= 2.29535
# differential_evolution step 301: f(x)= 2.29535
# differential_evolution step 302: f(x)= 2.29535
# differential_evolution step 303: f(x)= 2.28834
# differential_evolution step 304: f(x)= 2.28834
# differential_evolution step 305: f(x)= 2.28834
# differential_evolution step 306: f(x)= 2.24402
# differential_evolution step 307: f(x)= 2.24402
# differential_evolution step 308: f(x)= 2.24402
# differential_evolution step 309: f(x)= 2.24402
# differential_evolution step 310: f(x)= 2.24402
# differential_evolution step 311: f(x)= 2.24402
# differential_evolution step 312: f(x)= 2.24402
# differential_evolution step 313: f(x)= 2.24402
# differential_evolution step 314: f(x)= 2.24402
# differential_evolution step 315: f(x)= 2.24402
# differential_evolution step 316: f(x)= 2.24402
# differential_evolution step 317: f(x)= 2.24402
# differential_evolution step 318: f(x)= 2.24402
# differential_evolution step 319: f(x)= 2.24402
# differential_evolution step 320: f(x)= 2.24402
# differential_evolution step 321: f(x)= 2.24402
# differential_evolution step 322: f(x)= 2.24402
# differential_evolution step 323: f(x)= 2.24402
# differential_evolution step 324: f(x)= 2.24402
# differential_evolution step 325: f(x)= 2.24402
# differential_evolution step 326: f(x)= 2.24402
# differential_evolution step 327: f(x)= 2.24402
# differential_evolution step 328: f(x)= 2.24402
# differential_evolution step 329: f(x)= 2.24402
# differential_evolution step 330: f(x)= 2.24402
# differential_evolution step 331: f(x)= 2.24402
# differential_evolution step 332: f(x)= 2.24402
# differential_evolution step 333: f(x)= 2.24402
# differential_evolution step 334: f(x)= 2.22419
# differential_evolution step 335: f(x)= 2.22419
# differential_evolution step 336: f(x)= 2.22419
# differential_evolution step 337: f(x)= 2.22419
# differential_evolution step 338: f(x)= 2.22419
# differential_evolution step 339: f(x)= 2.22419
# differential_evolution step 340: f(x)= 2.22419
# differential_evolution step 341: f(x)= 2.22419
# differential_evolution step 342: f(x)= 2.22419
# differential_evolution step 343: f(x)= 2.22419
# differential_evolution step 344: f(x)= 2.22419
# differential_evolution step 345: f(x)= 2.22419
# differential_evolution step 346: f(x)= 2.22419
# differential_evolution step 347: f(x)= 2.22419
# differential_evolution step 348: f(x)= 2.22419
# differential_evolution step 349: f(x)= 2.22419
# differential_evolution step 350: f(x)= 2.22419
# differential_evolution step 351: f(x)= 2.22419
# differential_evolution step 352: f(x)= 2.22348
# differential_evolution step 353: f(x)= 2.22348
# differential_evolution step 354: f(x)= 2.22348
# differential_evolution step 355: f(x)= 2.22348
# differential_evolution step 356: f(x)= 2.19617
# differential_evolution step 357: f(x)= 2.19617
# differential_evolution step 358: f(x)= 2.19617
# differential_evolution step 359: f(x)= 2.19617
# differential_evolution step 360: f(x)= 2.19617
# differential_evolution step 361: f(x)= 2.19617
# differential_evolution step 362: f(x)= 2.19617
# differential_evolution step 363: f(x)= 2.19617
# differential_evolution step 364: f(x)= 2.19617
# differential_evolution step 365: f(x)= 2.19617
# differential_evolution step 366: f(x)= 2.19617
# differential_evolution step 367: f(x)= 2.19617
# differential_evolution step 368: f(x)= 2.19617
# differential_evolution step 369: f(x)= 2.19617
# differential_evolution step 370: f(x)= 2.19617
# differential_evolution step 371: f(x)= 2.19617
# differential_evolution step 372: f(x)= 2.19617
# differential_evolution step 373: f(x)= 2.19617
# differential_evolution step 374: f(x)= 2.19617
# differential_evolution step 375: f(x)= 2.19617
# differential_evolution step 376: f(x)= 2.19617
# differential_evolution step 377: f(x)= 2.19617
# differential_evolution step 378: f(x)= 2.19508
# differential_evolution step 379: f(x)= 2.19508
# differential_evolution step 380: f(x)= 2.19508
# differential_evolution step 381: f(x)= 2.19508
# differential_evolution step 382: f(x)= 2.19508
# differential_evolution step 383: f(x)= 2.19508
# differential_evolution step 384: f(x)= 2.19508
# differential_evolution step 385: f(x)= 2.18819
# differential_evolution step 386: f(x)= 2.18819
# differential_evolution step 387: f(x)= 2.18819
# differential_evolution step 388: f(x)= 2.18819
# differential_evolution step 389: f(x)= 2.1815
# differential_evolution step 390: f(x)= 2.1815
# differential_evolution step 391: f(x)= 2.1815
# differential_evolution step 392: f(x)= 2.1815
# differential_evolution step 393: f(x)= 2.1815
# differential_evolution step 394: f(x)= 2.1815
# differential_evolution step 395: f(x)= 2.1815
# differential_evolution step 396: f(x)= 2.1815
# differential_evolution step 397: f(x)= 2.1815
# differential_evolution step 398: f(x)= 2.1815
# differential_evolution step 399: f(x)= 2.1815
# differential_evolution step 400: f(x)= 2.1815
# differential_evolution step 401: f(x)= 2.1815
# differential_evolution step 402: f(x)= 2.1815
# differential_evolution step 403: f(x)= 2.1815
# differential_evolution step 404: f(x)= 2.1815
# differential_evolution step 405: f(x)= 2.1815
# differential_evolution step 406: f(x)= 2.1815
